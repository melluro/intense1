# %%
# !pip install cianparser
# Out:
# Collecting cianparser
#   Downloading cianparser-1.0.4-py3-none-any.whl.metadata (24 kB)
# Collecting cloudscraper (from cianparser)
#   Downloading cloudscraper-1.2.71-py2.py3-none-any.whl.metadata (19 kB)
# Collecting beautifulsoup4 (from cianparser)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting transliterate (from cianparser)
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl.metadata (14 kB)
# Collecting lxml (from cianparser)
#   Downloading lxml-5.3.0-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Collecting datetime (from cianparser)
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->cianparser)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyparsing>=2.4.7 (from cloudscraper->cianparser)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting requests>=2.9.2 (from cloudscraper->cianparser)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-toolbelt>=0.9.1 (from cloudscraper->cianparser)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zope.interface (from datetime->cianparser)
#   Downloading zope.interface-7.1.0-cp310-cp310-win_amd64.whl.metadata (45 kB)
# Collecting pytz (from datetime->cianparser)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: six>=1.1.0 in .\.venv\lib\site-packages (from transliterate->cianparser) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.9.2->cloudscraper->cianparser)
#   Downloading charset_normalizer-3.4.0-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.9.2->cloudscraper->cianparser)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.9.2->cloudscraper->cianparser)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.9.2->cloudscraper->cianparser)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: setuptools in .\.venv\lib\site-packages (from zope.interface->datetime->cianparser) (65.5.0)
# Downloading cianparser-1.0.4-py3-none-any.whl (32 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
# Downloading lxml-5.3.0-cp310-cp310-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 1.4 MB/s eta 0:00:03
#    -------- ------------------------------- 0.8/3.8 MB 1.5 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/3.8 MB 1.7 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.8 MB 1.9 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.8 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.1/3.8 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 1.7 MB/s eta 0:00:00
# Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading zope.interface-7.1.0-cp310-cp310-win_amd64.whl (211 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp310-cp310-win_amd64.whl (102 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: pytz, zope.interface, urllib3, transliterate, soupsieve, pyparsing, lxml, idna, charset-normalizer, certifi, requests, datetime, beautifulsoup4, requests-toolbelt, cloudscraper, cianparser
# Successfully installed beautifulsoup4-4.12.3 certifi-2024.8.30 charset-normalizer-3.4.0 cianparser-1.0.4 cloudscraper-1.2.71 datetime-5.5 idna-3.10 lxml-5.3.0 pyparsing-3.2.0 pytz-2024.2 requests-2.32.3 requests-toolbelt-1.0.0 soupsieve-2.6 transliterate-1.10.2 urllib3-2.2.3 zope.interface-7.1.0

# %%
import cianparser

moscow_parser = cianparser.CianParser(location="Лобня")
data = moscow_parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":1, "end_page":1000})

print(data[0])
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# d:\int1\cian_flat_sale_1_1000_lobnja_22_Oct_2024_16_34_44_944106.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 1 %. Average price: 28 040 824 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 2 page...
#
#
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 54. Progress ratio: 1 %. Average price: 31 790 018 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 4 page...
#
#
#  5 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 82. Progress ratio: 1 %. Average price: 35 070 615 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=6&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 6 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=7&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 7 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=8&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 8 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=9&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 9 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 10 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=11&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 11 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=12&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 12 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=13&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 13 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=14&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 14 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=15&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 15 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=16&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 16 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=17&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 17 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=18&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 18 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=19&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 19 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=20&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 20 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=21&with_neighbors=0&region=4848&deal_type=sale&offer_type=flat&room1=1&room2=1
# The collection of information from the pages with ending parse on 21 page...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 import cianparser
#       3 moscow_parser = cianparser.CianParser(location="Лобня")
# ----> 4 data = moscow_parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":1, "end_page":1000})
#       6 print(data[0])
#
# File d:\int1\.venv\lib\site-packages\cianparser\cianparser.py:119, in CianParser.get_flats(self, deal_type, rooms, with_saving_csv, with_extra_data, additional_settings)
#     108 deal_type, rent_period_type = __define_deal_type__(deal_type)
#     109 self.__parser__ = FlatListPageParser(
#     110     session=self.__session__,
#     111     accommodation_type="flat",
#    (...)
#     117     additional_settings=additional_settings,
#     118 )
# --> 119 self.__run__(
#     120     __build_url_list__(location_id=self.__location_id__, deal_type=deal_type, accommodation_type="flat",
#     121                        rooms=rooms, rent_period_type=rent_period_type,
#     122                        additional_settings=additional_settings))
#     123 return self.__parser__.result
#
# File d:\int1\.venv\lib\site-packages\cianparser\cianparser.py:76, in CianParser.__run__(self, url_list_format)
#      73 while attempt_number_exception < 3 and not page_parsed:
#      74     try:
#      75         (page_parsed, attempt_number, end_all_parsing) = self.__parser__.parse_list_offers_page(
# ---> 76             html=self.__load_list_page__(url_list_format=url_list_format, page_number=page_number, attempt_number_exception=attempt_number_exception),
#      77             page_number=page_number,
#      78             count_of_pages=self.__parser__.end_page + 1 - self.__parser__.start_page,
#      79             attempt_number=attempt_number_exception)
#      81     except Exception as e:
#      82         attempt_number_exception += 1
#
# File d:\int1\.venv\lib\site-packages\cianparser\cianparser.py:55, in CianParser.__load_list_page__(self, url_list_format, page_number, attempt_number_exception)
#      53 res = self.__session__.get(url=url_list)
#      54 if res.status_code == 429:
# ---> 55     time.sleep(10)
#      56 res.raise_for_status()
#      58 return res.text
#
# KeyboardInterrupt:
