# %%
import cianparser
import time 
import random
# Создаем экземпляр парсера
time.sleep(random.uniform(2, 4))
parser = cianparser.CianParser(location="Химки")

# Получаем данные
data = parser.get_flats(deal_type="sale", rooms=("studio", 1), additional_settings={"start_page": 55, "end_page": 200}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# f:\pr1\cian_flat_sale_55_200_himki_29_Oct_2024_11_27_18_333332.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=55&with_neighbors=0&region=5044&deal_type=sale&offer_type=flat&room9=1&room1=1
#
# ...
# 10
# 4
# 16 | 55 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 10 346 757 rub
# 6
# 18 | 55 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 12 750 257 rub
# 10
# 8
# 16 | 55 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 15 393 757 rub
# 6
# ...
